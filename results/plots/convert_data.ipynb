# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


results = pd.read_csv("./data/raw_data_3.csv")

# %%
#Elaborate data

#Group by comm_sz and pop_size
results_grouped = results.groupby(['comm_sz', 'pop_size']).agg(
    mean_time=('time', 'mean'),
    mean_best_value=('best_value', 'mean'),
).reset_index()


#Find, for each pop_size, calculate the speedup from the comm_sz = 1
for i in [50, 100, 200, 400, 800, 1600, 3200]:
    base_time = results_grouped.loc[(results_grouped['pop_size'] == i) & (results_grouped['comm_sz'] == 1), 'mean_time'].values[0]
    results_grouped.loc[results_grouped['pop_size'] == i, 'speedup'] = base_time / results_grouped.loc[results_grouped['pop_size'] == i, 'mean_time']
    results_grouped.loc[results_grouped['pop_size'] == i, 'efficiency'] = results_grouped.loc[results_grouped['pop_size'] == i, 'speedup'] / results_grouped.loc[results_grouped['pop_size'] == i, 'comm_sz']

print(results_grouped)

#Rename columns
results_grouped.rename(columns={
    'comm_sz': 'n_cores',
    'pop_size': 'n_agents',
    'mean_time': 'time',
    'mean_best_value': 'best_value',
}, inplace=True)

print(results_grouped)

results_grouped.to_csv("./data/avg_data.csv", index=False)
# Out:
#     comm_sz  pop_size    mean_time  mean_best_value    speedup  efficiency
# 0         1        50     1.397080    110993.732495   1.000000    1.000000
# 1         1       100     5.128673    106793.860401   1.000000    1.000000
# 2         1       200    19.430306     27026.498634   1.000000    1.000000
# 3         1       400    75.149092     10260.626093   1.000000    1.000000
# 4         1       800   295.430131      5734.560521   1.000000    1.000000
# 5         1      1600  1167.738182      2100.077799   1.000000    1.000000
# 6         1      3200  4655.891969      1027.758748   1.000000    1.000000
# 7         2        50     0.635331    162194.303901   2.198977    1.099489
# 8         2       100     2.355220     52658.656062   2.177577    1.088789
# 9         2       200     8.997785     31088.020423   2.159454    1.079727
# 10        2       400    35.183670     15859.130240   2.135908    1.067954
# 11        2       800   138.902522      7204.394738   2.126888    1.063444
# 12        2      1600   551.977667      2743.322823   2.115553    1.057777
# 13        2      3200  2198.259920      1258.891244   2.117990    1.058995
# 14        4        50     0.311414    127303.546828   4.486250    1.121563
# 15        4       100     1.061043     69034.688107   4.833616    1.208404
# 16        4       200     4.025230     32693.289339   4.827129    1.206782
# 17        4       400    15.718245     11322.452274   4.781010    1.195253
# 18        4       800    61.990893      5556.061155   4.765702    1.191426
# 19        4      1600   246.261836      2352.676076   4.741856    1.185464
# 20        4      3200   981.066557       800.673824   4.745745    1.186436
# 21        8        50     0.182835    139992.746100   7.641204    0.955150
# 22        8       100     0.596251     69556.096351   8.601532    1.075191
# 23        8       200     2.151203     30099.765912   9.032297    1.129037
# 24        8       400     8.171061     12599.844097   9.196981    1.149623
# 25        8       800    32.201425      6502.147706   9.174443    1.146805
# 26        8      1600   129.674377      2184.343406   9.005157    1.125645
# 27        8      3200   511.021262      1157.676752   9.110955    1.138869
# 28       16        50     0.149015    128101.268075   9.375429    0.585964
# 29       16       100     0.427231     59224.966253  12.004442    0.750278
# 30       16       200     1.435557     29323.843582  13.535026    0.845939
# 31       16       400     5.232381     13078.753335  14.362311    0.897644
# 32       16       800    20.360233      6485.408273  14.510155    0.906885
# 33       16      1600    80.503199      2476.768734  14.505488    0.906593
# 34       16      3200   323.941217      1042.560060  14.372645    0.898290
# 35       32        50     0.114101    133968.399756  12.244232    0.382632
# 36       32       100     0.291570     71254.538024  17.589829    0.549682
# 37       32       200     0.856722     32684.354764  22.679821    0.708744
# 38       32       400     2.880960     12100.933433  26.084743    0.815148
