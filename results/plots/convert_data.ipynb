# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


results = pd.read_csv("./data/raw_data_2.csv")

# %%
#Elaborate data

#Group by comm_sz and pop_size
results_grouped = results.groupby(['comm_sz', 'pop_size']).agg(
    mean_time=('time', 'mean'),
    mean_best_value=('best_value', 'mean'),
).reset_index()


#Find, for each pop_size, calculate the speedup from the comm_sz = 1
for i in [50, 100, 200, 400, 800, 1600, 3200]:
    base_time = results_grouped.loc[(results_grouped['pop_size'] == i) & (results_grouped['comm_sz'] == 1), 'mean_time'].values[0]
    results_grouped.loc[results_grouped['pop_size'] == i, 'speedup'] = base_time / results_grouped.loc[results_grouped['pop_size'] == i, 'mean_time']
    results_grouped.loc[results_grouped['pop_size'] == i, 'efficiency'] = results_grouped.loc[results_grouped['pop_size'] == i, 'speedup'] / results_grouped.loc[results_grouped['pop_size'] == i, 'comm_sz']

print(results_grouped)

#Rename columns
results_grouped.rename(columns={
    'comm_sz': 'n_cores',
    'pop_size': 'n_agents',
    'mean_time': 'time',
    'mean_best_value': 'best_value',
}, inplace=True)

print(results_grouped)

results_grouped.to_csv("./data/avg_data.csv", index=False)
# Out:
#     comm_sz  pop_size    mean_time  mean_best_value    speedup  efficiency
# 0         1        50     1.325976    165769.745573   1.000000    1.000000
# 1         1       100     4.848469     59044.882207   1.000000    1.000000
# 2         1       200    18.332924     22576.172735   1.000000    1.000000
# 3         1       400    70.863241      9774.955660   1.000000    1.000000
# 4         1       800   278.085575      6412.284222   1.000000    1.000000
# 5         1      1600  1099.967181      3833.792178   1.000000    1.000000
# 6         1      3200  4378.918678      1069.579837   1.000000    1.000000
# 7         2        50     0.573104    143888.789926   2.313676    1.156838
# 8         2       100     2.124088     80690.264603   2.282612    1.141306
# 9         2       200     8.205139     34122.427775   2.234322    1.117161
# 10        2       400    32.060961     18084.189109   2.210266    1.105133
# 11        2       800   126.853622      5182.652820   2.192177    1.096088
# 12        2      1600   503.769832      2959.293742   2.183472    1.091736
# 13        2      3200  2010.058348       691.808708   2.178503    1.089252
# 14        4        50     0.323688    174763.537688   4.096460    1.024115
# 15        4       100     1.131940     58815.116504   4.283328    1.070832
# 16        4       200     4.331708     37303.227568   4.232262    1.058066
# 17        4       400    16.897350     15734.749669   4.193749    1.048437
# 18        4       800    66.747607      6988.312472   4.166225    1.041556
# 19        4      1600   264.604987      3256.744954   4.157016    1.039254
# 20        4      3200  1038.647720       945.791552   4.215981    1.053995
# 21        8        50     0.197759    134749.485153   6.705018    0.838127
# 22        8       100     0.613409     56951.148130   7.904136    0.988017
# 23        8       200     2.307907     25948.449984   7.943529    0.992941
# 24        8       400     8.586606     16808.545613   8.252765    1.031596
# 25        8       800    33.462513      6477.336590   8.310361    1.038795
# 26        8      1600   133.230673      2170.593515   8.256111    1.032014
# 27        8      3200   528.934146       951.890624   8.278760    1.034845
# 28       16        50     0.130690    137379.694321  10.145943    0.634121
# 29       16       100     0.366618     54094.592821  13.224854    0.826553
# 30       16       200     1.229839     29409.066082  14.906763    0.931673
# 31       16       400     4.496409     15862.980056  15.759965    0.984998
# 32       16       800    17.481872      7489.741578  15.907082    0.994193
# 33       16      1600    68.937772      2536.496344  15.955943    0.997246
# 34       16      3200   273.588614       574.838344  16.005486    1.000343
# 35       32        50     0.109840    156107.539628  12.071841    0.377245
# 36       32       100     0.279187     64704.885998  17.366382    0.542699
# 37       32       200     0.824411     29516.140895  22.237607    0.694925
# 38       32       400     2.633122     14791.485798  26.912249    0.841008
# 39       32       800     9.379133      9137.757083  29.649389    0.926543
# 40       32      1600    36.688955      3083.068231  29.980881    0.936903
# 41       32      3200   143.699726      1232.320445  30.472700    0.952272
# 42       64        50     0.100193    139580.775292  13.234270    0.206785
# 43       64       100     0.216189     55234.195500  22.427022    0.350422
# 44       64       200     0.568954     37029.295210  32.222163    0.503471
# 45       64       400     1.812776     13567.924624  39.091001    0.610797
# 46       64       800     6.091940      6387.148491  45.648112    0.713252
# 47       64      1600    22.043058      2407.379032  49.900844    0.779701
# 48       64      3200    84.391385       846.440762  51.888219    0.810753
#     n_cores  n_agents         time     best_value    speedup  efficiency
# 0         1        50     1.325976  165769.745573   1.000000    1.000000
# 1         1       100     4.848469   59044.882207   1.000000    1.000000
# 2         1       200    18.332924   22576.172735   1.000000    1.000000
# 3         1       400    70.863241    9774.955660   1.000000    1.000000
# 4         1       800   278.085575    6412.284222   1.000000    1.000000
# 5         1      1600  1099.967181    3833.792178   1.000000    1.000000
# 6         1      3200  4378.918678    1069.579837   1.000000    1.000000
# 7         2        50     0.573104  143888.789926   2.313676    1.156838
# 8         2       100     2.124088   80690.264603   2.282612    1.141306
# 9         2       200     8.205139   34122.427775   2.234322    1.117161
# 10        2       400    32.060961   18084.189109   2.210266    1.105133
# 11        2       800   126.853622    5182.652820   2.192177    1.096088
# 12        2      1600   503.769832    2959.293742   2.183472    1.091736
# 13        2      3200  2010.058348     691.808708   2.178503    1.089252
# 14        4        50     0.323688  174763.537688   4.096460    1.024115
# 15        4       100     1.131940   58815.116504   4.283328    1.070832
# 16        4       200     4.331708   37303.227568   4.232262    1.058066
# 17        4       400    16.897350   15734.749669   4.193749    1.048437
# 18        4       800    66.747607    6988.312472   4.166225    1.041556
# 19        4      1600   264.604987    3256.744954   4.157016    1.039254
# 20        4      3200  1038.647720     945.791552   4.215981    1.053995
# 21        8        50     0.197759  134749.485153   6.705018    0.838127
# 22        8       100     0.613409   56951.148130   7.904136    0.988017
# 23        8       200     2.307907   25948.449984   7.943529    0.992941
# 24        8       400     8.586606   16808.545613   8.252765    1.031596
# 25        8       800    33.462513    6477.336590   8.310361    1.038795
# 26        8      1600   133.230673    2170.593515   8.256111    1.032014
# 27        8      3200   528.934146     951.890624   8.278760    1.034845
# 28       16        50     0.130690  137379.694321  10.145943    0.634121
# 29       16       100     0.366618   54094.592821  13.224854    0.826553
# 30       16       200     1.229839   29409.066082  14.906763    0.931673
# 31       16       400     4.496409   15862.980056  15.759965    0.984998
# 32       16       800    17.481872    7489.741578  15.907082    0.994193
# 33       16      1600    68.937772    2536.496344  15.955943    0.997246
# 34       16      3200   273.588614     574.838344  16.005486    1.000343
# 35       32        50     0.109840  156107.539628  12.071841    0.377245
# 36       32       100     0.279187   64704.885998  17.366382    0.542699
# 37       32       200     0.824411   29516.140895  22.237607    0.694925
# 38       32       400     2.633122   14791.485798  26.912249    0.841008
# 39       32       800     9.379133    9137.757083  29.649389    0.926543
# 40       32      1600    36.688955    3083.068231  29.980881    0.936903
# 41       32      3200   143.699726    1232.320445  30.472700    0.952272
# 42       64        50     0.100193  139580.775292  13.234270    0.206785
# 43       64       100     0.216189   55234.195500  22.427022    0.350422
# 44       64       200     0.568954   37029.295210  32.222163    0.503471
# 45       64       400     1.812776   13567.924624  39.091001    0.610797
# 46       64       800     6.091940    6387.148491  45.648112    0.713252
# 47       64      1600    22.043058    2407.379032  49.900844    0.779701
# 48       64      3200    84.391385     846.440762  51.888219    0.810753
