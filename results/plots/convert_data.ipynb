# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


results = pd.read_csv("./data/raw_data.csv")

# %%
#Elaborate data

#Group by comm_sz and pop_size
results_grouped = results.groupby(['comm_sz', 'pop_size']).agg(
    mean_time=('time', 'mean'),
    mean_best_value=('best_value', 'mean'),
).reset_index()


#Find, for each pop_size, calculate the speedup from the comm_sz = 1
for i in [50, 100, 200, 400, 800, 1600, 3200]:
    base_time = results_grouped.loc[(results_grouped['pop_size'] == i) & (results_grouped['comm_sz'] == 1), 'mean_time'].values[0]
    results_grouped.loc[results_grouped['pop_size'] == i, 'speedup'] = base_time / results_grouped.loc[results_grouped['pop_size'] == i, 'mean_time']
    results_grouped.loc[results_grouped['pop_size'] == i, 'efficiency'] = results_grouped.loc[results_grouped['pop_size'] == i, 'speedup'] / results_grouped.loc[results_grouped['pop_size'] == i, 'comm_sz']

print(results_grouped)

#Rename columns
results_grouped.rename(columns={
    'comm_sz': 'n_cores',
    'pop_size': 'n_agents',
    'mean_time': 'time',
    'mean_best_value': 'best_value',
}, inplace=True)

print(results_grouped)

results_grouped.to_csv("./data/avg_data.csv", index=False)
# Out:
#     comm_sz  pop_size    mean_time  mean_best_value    speedup  efficiency
# 0         1        50     1.376482    145236.748493   1.000000    1.000000
# 1         1       100     5.055487    145384.432121   1.000000    1.000000
# 2         1       200    19.052586     43321.427520   1.000000    1.000000
# 3         1       400    73.675399     17781.445960   1.000000    1.000000
# 4         1       800   289.486958      5661.424146   1.000000    1.000000
# 5         1      1600  1145.247574      3172.378479   1.000000    1.000000
# 6         1      3200  4552.875567      1094.003632   1.000000    1.000000
# 7         2        50     0.653408    159848.463610   2.106620    1.053310
# 8         2       100     2.402442     88975.445632   2.104312    1.052156
# 9         2       200     9.214508     31955.349393   2.067673    1.033836
# 10        2       400    36.016890     14899.779415   2.045579    1.022790
# 11        2       800   142.834663      7936.655727   2.026728    1.013364
# 12        2      1600   566.090552      2552.922081   2.023082    1.011541
# 13        2      3200  2258.580689      1267.477475   2.015813    1.007906
# 14        4        50     0.352689    124032.772489   3.902820    0.975705
# 15        4       100     1.206295     81374.239820   4.190920    1.047730
# 16        4       200     4.557998     35969.405859   4.180034    1.045008
# 17        4       400    17.771114     15774.199190   4.145795    1.036449
# 18        4       800    73.980553      9096.122377   3.913014    0.978254
# 19        4      1600   278.093849      2315.557043   4.118205    1.029551
# 20        4      3200  1108.480984      1054.697522   4.107310    1.026828
# 21        8        50     0.188489    134948.096571   7.302719    0.912840
# 22        8       100     0.601078     70630.129624   8.410695    1.051337
# 23        8       200     2.138803     38637.116412   8.908059    1.113507
# 24        8       400     8.205146     19846.399583   8.979169    1.122396
# 25        8       800    32.322916      7089.901150   8.956090    1.119511
# 26        8      1600   128.648208      3524.312114   8.902165    1.112771
# 27        8      3200   516.847484      1048.719919   8.808934    1.101117
# 28       16        50     0.152936    112613.496683   9.000375    0.562523
# 29       16       100     0.420911     68138.954188  12.010826    0.750677
# 30       16       200     1.369324     34496.697349  13.913860    0.869616
# 31       16       400     5.009483     14427.739837  14.707186    0.919199
# 32       16       800    19.470950      7680.438304  14.867634    0.929227
# 33       16      1600    76.980487      2739.885903  14.877115    0.929820
# 34       16      3200   313.269092      1303.760551  14.533434    0.908340
# 35       32        50     0.126431    126446.301478  10.887176    0.340224
# 36       32       100     0.309068     62407.874581  16.357217    0.511163
# 37       32       200     0.896836     36460.510493  21.244214    0.663882
# 38       32       400     3.015101     16263.701212  24.435466    0.763608
# 39       32       800    10.714567      8645.812083  27.018074    0.844315
